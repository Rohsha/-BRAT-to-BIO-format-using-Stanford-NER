# %%
# Code to convert brat annotated format to the formats required by spaCy and CRF NRF models, and to include BIO tags

# Usage:
# 1) Install the pycorenlp package
# 2) Run CoreNLP server (change STANFORD_SERVER_ADDRESS if needed)
# 3) Place .ann and .txt files from brat in the location specified in DATA_DIRECTORY
# 4) Run this script

# Cross-sentence annotation is not supported

from pycorenlp import StanfordCoreNLP
import os
from os import listdir
from os.path import isfile, join

OTHER_ANNO = 'O'
ENTITY_PREFIX = 'T'
RELATION_PREFIX = 'R'
DATA_DIRECTORY = "C:\\Users\\rohin\\Rohini_Mondaq_Dessertation\\mondaq_data_project1_set2"
OUTPUT_DIRECTORY = 'C:\\Users\\rohin\\Rohini_Mondaq_Dessertation\\mondaq_data_project1_set2\\output'
STANFORD_SERVER_ADDRESS = 'http://localhost:9000'

NER_TRAINING_DATA_OUTPUT_PATH = join(OUTPUT_DIRECTORY, 'ner-crf-data.tsv')
RE_TRAINING_DATA_OUTPUT_PATH = join(OUTPUT_DIRECTORY, 're-data.corp')

if os.path.exists(OUTPUT_DIRECTORY):
	if os.path.exists(NER_TRAINING_DATA_OUTPUT_PATH):
		os.remove(NER_TRAINING_DATA_OUTPUT_PATH)
	if os.path.exists(RE_TRAINING_DATA_OUTPUT_PATH):
		os.remove(RE_TRAINING_DATA_OUTPUT_PATH)
else:
    os.makedirs(OUTPUT_DIRECTORY)

sentence_count = 1
nlp = StanfordCoreNLP(STANFORD_SERVER_ADDRESS)

# looping through .ann files in the data directory
ann_data_files = [f for f in listdir(DATA_DIRECTORY) if isfile(join(DATA_DIRECTORY, f)) and f.split('.')[1] == 'ann']

for file in ann_data_files:
	entities = []
	relations = []

	# process .ann file - place entities and relations into 2 seperate lists of tuples
	with open(join(DATA_DIRECTORY, file), 'r',encoding="utf8") as document_anno_file:
		lines = document_anno_file.readlines()
		for line in lines:
			standoff_line = line.split()
			if standoff_line[0][0] == ENTITY_PREFIX:
				entity = {}
				entity['standoff_id'] = int(standoff_line[0][1:])
				entity['entity_type'] = standoff_line[1].capitalize()
				entity['offset_start'] = int(standoff_line[2])
				entity['offset_end'] = int(standoff_line[3])
				entity['word'] = standoff_line[4]
				entities.append(entity)

			elif standoff_line[0][0] == RELATION_PREFIX:
				relation = {}
				relation['standoff_id'] = int(standoff_line[0][1:])
				relation['name'] = standoff_line[1]
				relation['standoff_entity1_id'] = int(standoff_line[2].split(':')[1][1:])
				relation['standoff_entity2_id'] = int(standoff_line[3].split(':')[1][1:])
				relations.append(relation)
				# relations.append((standoff_id, relation_name, standoff_entity1_id, standoff_entity2_id))

	# read the .ann's matching .txt file and tokenize its text using stanford corenlp
	with open(join(DATA_DIRECTORY, file.replace('.ann', '.txt')), 'r',encoding="utf8") as document_text_file:
		document_text = document_text_file.read()

	output = nlp.annotate(document_text, properties={
	  'annotators': 'tokenize,ssplit,pos',
	  'outputFormat': 'json'
	})

	# write text and annotations into NER and RE output files
	with open(NER_TRAINING_DATA_OUTPUT_PATH, 'a',encoding="utf-8") as ner_training_data, open(RE_TRAINING_DATA_OUTPUT_PATH, 'a',encoding="utf-8") as re_training_data:
		for sentence in output['sentences']:
			entities_in_sentence = {}
			sentence_re_rows = []

			for token in sentence['tokens']:
				offset_start = int(token['characterOffsetBegin'])
				offset_end = int(token['characterOffsetEnd'])

				re_row = {}
				entity_found = False
				ner_anno = OTHER_ANNO

				# searching for token in annotated entities. 
				# If the token appears in the beginning, prefix with B-, 
				# if the token appears in between first and last word, prefix with I-, 
				# and for the last token, prefix with O-
				for entity in entities:
					if offset_start == entity['offset_start'] and offset_end <= entity['offset_end']:
						ner_anno = 'B-'+entity['entity_type']
					if offset_start > entity['offset_start'] and offset_end < entity['offset_end']:
						ner_anno = 'I-'+entity['entity_type']
					if offset_start > entity['offset_start'] and offset_end == entity['offset_end']:
						ner_anno = 'O-'+entity['entity_type']
                        
					# multi-token entities for RE need to be handled differently than NER
					if offset_start == entity['offset_start'] and offset_end <= entity['offset_end']:
						entities_in_sentence[entity['standoff_id']] = len(sentence_re_rows)
						re_row['entity_type'] = 'B-'+entity['entity_type']
						re_row['pos_tag'] = token['pos']
						re_row['word'] = token['word']

						sentence_re_rows.append(re_row)
						entity_found = True
						break
					#elif offset_start > entity['offset_start'] and offset_end <= entity['offset_end'] and len(sentence_re_rows) > 0:
					elif offset_start > entity['offset_start'] and offset_end < entity['offset_end']:
						re_row['entity_type'] = 'I-'+entity['entity_type']
						re_row['pos_tag'] = token['pos']
						re_row['word'] = token['word']
						sentence_re_rows.append(re_row)
						entity_found = True
						break
					elif offset_start > entity['offset_start'] and offset_end == entity['offset_end']:
						re_row['entity_type'] = 'O-'+entity['entity_type']
						re_row['pos_tag'] = token['pos']
						re_row['word'] = token['word']
						sentence_re_rows.append(re_row)
						entity_found = True
						break

                        
                        
				if not entity_found:
					re_row['entity_type'] = OTHER_ANNO
					re_row['pos_tag'] = token['pos']
					re_row['word'] = token['word']

					sentence_re_rows.append(re_row)

				# writing tagged tokens to NER training data
				ner_training_data.write('{}\t{}\n'.format(token['word'], ner_anno))

			# writing tagged tokens to RE training data
			token_count = 0
			for sentence_row in sentence_re_rows:
				re_training_data.write('{}\t{}\t{}\t{}\n'.format(str(sentence_count), sentence_row['entity_type'], sentence_row['pos_tag'], sentence_row['word']))
				token_count += 1

			# re_training_data.write('\n')

			# writing relations to RE training data
			for relation in relations:
				if relation['standoff_entity1_id'] in entities_in_sentence and relation['standoff_entity2_id'] in entities_in_sentence:
					entity1 = str(entities_in_sentence[relation['standoff_entity1_id']])
					entity2 = str(entities_in_sentence[relation['standoff_entity2_id']])
					relation_name = relation['name']
					re_training_data.write('{}\t{}\t{}\n'.format(entity1, entity2, relation_name))

			# re_training_data.write('\n')

			sentence_count += 1

		# ner_training_data.write('\n')

	print('Processed file pair: {} and {}'.format(file, file.replace('.ann', '.txt')))
# Out:
# Processed file pair: 899190.ann and 899190.txt
# Processed file pair: 899192.ann and 899192.txt
# Processed file pair: 899194.ann and 899194.txt
# Processed file pair: 899196.ann and 899196.txt
# Processed file pair: 899198.ann and 899198.txt
# Processed file pair: 899200.ann and 899200.txt
# Processed file pair: 899202.ann and 899202.txt
# Processed file pair: 899206.ann and 899206.txt
# Processed file pair: 899208.ann and 899208.txt
# Processed file pair: 899210.ann and 899210.txt
# Processed file pair: 899212.ann and 899212.txt
# Processed file pair: 899214.ann and 899214.txt
# Processed file pair: 899216.ann and 899216.txt
# Processed file pair: 899218.ann and 899218.txt
# Processed file pair: 899220.ann and 899220.txt
# Processed file pair: 899222.ann and 899222.txt
# Processed file pair: 899224.ann and 899224.txt
# Processed file pair: 899226.ann and 899226.txt
# Processed file pair: 899228.ann and 899228.txt
# Processed file pair: 899230.ann and 899230.txt
# Processed file pair: 899232.ann and 899232.txt
# Processed file pair: 899234.ann and 899234.txt
# Processed file pair: 899236.ann and 899236.txt
# Processed file pair: 899238.ann and 899238.txt
# Processed file pair: 899240.ann and 899240.txt
# Processed file pair: 899242.ann and 899242.txt
# Processed file pair: 899244.ann and 899244.txt
# Processed file pair: 899246.ann and 899246.txt
# Processed file pair: 899248.ann and 899248.txt
# Processed file pair: 899250.ann and 899250.txt
# Processed file pair: 899252.ann and 899252.txt
# Processed file pair: 899254.ann and 899254.txt
# Processed file pair: 899256.ann and 899256.txt
# Processed file pair: 899258.ann and 899258.txt
# Processed file pair: 899260.ann and 899260.txt
# Processed file pair: 899262.ann and 899262.txt
# Processed file pair: 899264.ann and 899264.txt
# Processed file pair: 899266.ann and 899266.txt
# Processed file pair: 899268.ann and 899268.txt
# Processed file pair: 899270.ann and 899270.txt
# Processed file pair: 899272.ann and 899272.txt
# Processed file pair: 899276.ann and 899276.txt
# Processed file pair: 899278.ann and 899278.txt
# Processed file pair: 899280.ann and 899280.txt
# Processed file pair: 899282.ann and 899282.txt
# Processed file pair: 899284.ann and 899284.txt
# Processed file pair: 899288.ann and 899288.txt
# Processed file pair: 899290.ann and 899290.txt
# Processed file pair: 899292.ann and 899292.txt
# Processed file pair: 899294.ann and 899294.txt
# Processed file pair: 899296.ann and 899296.txt
# Processed file pair: 899298.ann and 899298.txt
# Processed file pair: 899300.ann and 899300.txt
# Processed file pair: 899302.ann and 899302.txt
# Processed file pair: 899304.ann and 899304.txt
# Processed file pair: 899306.ann and 899306.txt
# Processed file pair: 899308.ann and 899308.txt
# Processed file pair: 899310.ann and 899310.txt
# Processed file pair: 899312.ann and 899312.txt
# Processed file pair: 899314.ann and 899314.txt
# Processed file pair: 899316.ann and 899316.txt
# Processed file pair: 899318.ann and 899318.txt
# Processed file pair: 899320.ann and 899320.txt
# Processed file pair: 899322.ann and 899322.txt
# Processed file pair: 899324.ann and 899324.txt
# Processed file pair: 899326.ann and 899326.txt
# Processed file pair: 899328.ann and 899328.txt
# Processed file pair: 899330.ann and 899330.txt
# Processed file pair: 899332.ann and 899332.txt
# Processed file pair: 899336.ann and 899336.txt
# Processed file pair: 899338.ann and 899338.txt
# Processed file pair: 899340.ann and 899340.txt
# Processed file pair: 899342.ann and 899342.txt
# Processed file pair: 899344.ann and 899344.txt
# Processed file pair: 899348.ann and 899348.txt
# Processed file pair: 899350.ann and 899350.txt
# Processed file pair: 899352.ann and 899352.txt
# Processed file pair: 899354.ann and 899354.txt
# Processed file pair: 899358.ann and 899358.txt
# Processed file pair: 899360.ann and 899360.txt
# Processed file pair: 899364.ann and 899364.txt
# Processed file pair: 899368.ann and 899368.txt
# Processed file pair: 899370.ann and 899370.txt
# Processed file pair: 899372.ann and 899372.txt
# Processed file pair: 899374.ann and 899374.txt
# Processed file pair: 899376.ann and 899376.txt
# Processed file pair: 899378.ann and 899378.txt
# Processed file pair: 899380.ann and 899380.txt
# Processed file pair: 899382.ann and 899382.txt
# Processed file pair: 899384.ann and 899384.txt
# Processed file pair: 899386.ann and 899386.txt
# Processed file pair: 899388.ann and 899388.txt
# Processed file pair: 899390.ann and 899390.txt
# Processed file pair: 899392.ann and 899392.txt
# Processed file pair: 899396.ann and 899396.txt
# Processed file pair: 899398.ann and 899398.txt
# Processed file pair: 899400.ann and 899400.txt
# Processed file pair: 899402.ann and 899402.txt
# Processed file pair: 899404.ann and 899404.txt
# Processed file pair: 899406.ann and 899406.txt
# Processed file pair: 899408.ann and 899408.txt
# Processed file pair: 899410.ann and 899410.txt
# Processed file pair: 899412.ann and 899412.txt
# Processed file pair: 899414.ann and 899414.txt
# Processed file pair: 899416.ann and 899416.txt
# Processed file pair: 899418.ann and 899418.txt
# Processed file pair: 899422.ann and 899422.txt
# Processed file pair: 899424.ann and 899424.txt
# Processed file pair: 899426.ann and 899426.txt
# Processed file pair: 899428.ann and 899428.txt
# Processed file pair: 899430.ann and 899430.txt
# Processed file pair: 899432.ann and 899432.txt
# Processed file pair: 899436.ann and 899436.txt
# Processed file pair: 899438.ann and 899438.txt
# Processed file pair: 899440.ann and 899440.txt
# Processed file pair: 899444.ann and 899444.txt
# Processed file pair: 899446.ann and 899446.txt
# Processed file pair: 899450.ann and 899450.txt
# Processed file pair: 899454.ann and 899454.txt
# Processed file pair: 899456.ann and 899456.txt
# Processed file pair: 899458.ann and 899458.txt
# Processed file pair: 899460.ann and 899460.txt
# Processed file pair: 899462.ann and 899462.txt
# Processed file pair: 899464.ann and 899464.txt
# Processed file pair: 899470.ann and 899470.txt
# Processed file pair: 899472.ann and 899472.txt
# Processed file pair: 899474.ann and 899474.txt
# Processed file pair: 899476.ann and 899476.txt
# Processed file pair: 899478.ann and 899478.txt
# Processed file pair: 899480.ann and 899480.txt
# Processed file pair: 899484.ann and 899484.txt
# Processed file pair: 899486.ann and 899486.txt
# Processed file pair: 899488.ann and 899488.txt
# Processed file pair: 899490.ann and 899490.txt
# Processed file pair: 899492.ann and 899492.txt
# Processed file pair: 899494.ann and 899494.txt
# Processed file pair: 899496.ann and 899496.txt
# Processed file pair: 899498.ann and 899498.txt
# Processed file pair: 899500.ann and 899500.txt
# Processed file pair: 899502.ann and 899502.txt
# Processed file pair: 899504.ann and 899504.txt
# Processed file pair: 899506.ann and 899506.txt
# Processed file pair: 899508.ann and 899508.txt
# Processed file pair: 899510.ann and 899510.txt
# Processed file pair: 899512.ann and 899512.txt
# Processed file pair: 899514.ann and 899514.txt
# Processed file pair: 899516.ann and 899516.txt
# Processed file pair: 899518.ann and 899518.txt
# Processed file pair: 899520.ann and 899520.txt
# Processed file pair: 899524.ann and 899524.txt
# Processed file pair: 899526.ann and 899526.txt
# Processed file pair: 899528.ann and 899528.txt
# Processed file pair: 899530.ann and 899530.txt
# Processed file pair: 899532.ann and 899532.txt
# Processed file pair: 899534.ann and 899534.txt
# Processed file pair: 899536.ann and 899536.txt
# Processed file pair: 899538.ann and 899538.txt
# Processed file pair: 899540.ann and 899540.txt
# Processed file pair: 899542.ann and 899542.txt
# Processed file pair: 899544.ann and 899544.txt
# Processed file pair: 899546.ann and 899546.txt
# Processed file pair: 899548.ann and 899548.txt
# Processed file pair: 899550.ann and 899550.txt
# Processed file pair: 899552.ann and 899552.txt
# Processed file pair: 899554.ann and 899554.txt
# Processed file pair: 899556.ann and 899556.txt
# Processed file pair: 899558.ann and 899558.txt
# Processed file pair: 899560.ann and 899560.txt
# Processed file pair: 899562.ann and 899562.txt
# Processed file pair: 899564.ann and 899564.txt
# Processed file pair: 899568.ann and 899568.txt
# Processed file pair: 899570.ann and 899570.txt
# Processed file pair: 899572.ann and 899572.txt
# Processed file pair: 899574.ann and 899574.txt
# Processed file pair: 899576.ann and 899576.txt
# Processed file pair: 899578.ann and 899578.txt
# Processed file pair: 899580.ann and 899580.txt
# Processed file pair: 899582.ann and 899582.txt
# Processed file pair: 899584.ann and 899584.txt
# Processed file pair: 899586.ann and 899586.txt
# Processed file pair: 899588.ann and 899588.txt
# Processed file pair: 899592.ann and 899592.txt
# Processed file pair: 899594.ann and 899594.txt
# Processed file pair: 899596.ann and 899596.txt
# Processed file pair: 899598.ann and 899598.txt
# Processed file pair: 899600.ann and 899600.txt
# Processed file pair: 899602.ann and 899602.txt
# Processed file pair: 899604.ann and 899604.txt
# Processed file pair: 899606.ann and 899606.txt
# Processed file pair: 899608.ann and 899608.txt
# Processed file pair: 899610.ann and 899610.txt
# Processed file pair: 899612.ann and 899612.txt
# Processed file pair: 899614.ann and 899614.txt
# Processed file pair: 899616.ann and 899616.txt
# Processed file pair: 899620.ann and 899620.txt
# Processed file pair: 899622.ann and 899622.txt
# Processed file pair: 899624.ann and 899624.txt
# Processed file pair: 899626.ann and 899626.txt
# Processed file pair: 899628.ann and 899628.txt
# Processed file pair: 899630.ann and 899630.txt
# Processed file pair: 899632.ann and 899632.txt
# Processed file pair: 899634.ann and 899634.txt
# Processed file pair: 899636.ann and 899636.txt
# Processed file pair: 899638.ann and 899638.txt
# Processed file pair: 899642.ann and 899642.txt
# Processed file pair: 899644.ann and 899644.txt
# Processed file pair: 899648.ann and 899648.txt
# Processed file pair: 899650.ann and 899650.txt
# Processed file pair: 899654.ann and 899654.txt
# Processed file pair: 899656.ann and 899656.txt
# Processed file pair: 899658.ann and 899658.txt
# Processed file pair: 899660.ann and 899660.txt
# Processed file pair: 899662.ann and 899662.txt
# Processed file pair: 899664.ann and 899664.txt
# Processed file pair: 899666.ann and 899666.txt
# Processed file pair: 899668.ann and 899668.txt
# Processed file pair: 899670.ann and 899670.txt
# Processed file pair: 899672.ann and 899672.txt
# Processed file pair: 899674.ann and 899674.txt
# Processed file pair: 899676.ann and 899676.txt
# Processed file pair: 899678.ann and 899678.txt
# Processed file pair: 899680.ann and 899680.txt
# Processed file pair: 899682.ann and 899682.txt
# Processed file pair: 899684.ann and 899684.txt
# Processed file pair: 899686.ann and 899686.txt
# Processed file pair: 899688.ann and 899688.txt
# Processed file pair: 899690.ann and 899690.txt
# Processed file pair: 899692.ann and 899692.txt
# Processed file pair: 899694.ann and 899694.txt
# Processed file pair: 899696.ann and 899696.txt
# Processed file pair: 899698.ann and 899698.txt
# Processed file pair: 899700.ann and 899700.txt
# Processed file pair: 899702.ann and 899702.txt
# Processed file pair: 899704.ann and 899704.txt
# Processed file pair: 899706.ann and 899706.txt
# Processed file pair: 899708.ann and 899708.txt
# Processed file pair: 899710.ann and 899710.txt
# Processed file pair: 899712.ann and 899712.txt
# Processed file pair: 899718.ann and 899718.txt
# Processed file pair: 899724.ann and 899724.txt
# Processed file pair: 899726.ann and 899726.txt
# Processed file pair: 899728.ann and 899728.txt
# Processed file pair: 899730.ann and 899730.txt
# Processed file pair: 899732.ann and 899732.txt
# Processed file pair: 899734.ann and 899734.txt
# Processed file pair: 899736.ann and 899736.txt
# Processed file pair: 899738.ann and 899738.txt
# Processed file pair: 899742.ann and 899742.txt
# Processed file pair: 899744.ann and 899744.txt
# Processed file pair: 899746.ann and 899746.txt
# Processed file pair: 899748.ann and 899748.txt
# Processed file pair: 899750.ann and 899750.txt
# Processed file pair: 899754.ann and 899754.txt
# Processed file pair: 899756.ann and 899756.txt
# Processed file pair: 899758.ann and 899758.txt
# Processed file pair: 899764.ann and 899764.txt
# Processed file pair: 899766.ann and 899766.txt
# Processed file pair: 899768.ann and 899768.txt
# Processed file pair: 899772.ann and 899772.txt
# Processed file pair: 899774.ann and 899774.txt
# Processed file pair: 899778.ann and 899778.txt
# Processed file pair: 899780.ann and 899780.txt
# Processed file pair: 899784.ann and 899784.txt
# Processed file pair: 899786.ann and 899786.txt
# Processed file pair: 899788.ann and 899788.txt
# Processed file pair: 899790.ann and 899790.txt
# Processed file pair: 899792.ann and 899792.txt
# Processed file pair: 899794.ann and 899794.txt
# Processed file pair: 899796.ann and 899796.txt
# Processed file pair: 899798.ann and 899798.txt
# Processed file pair: 899802.ann and 899802.txt
# Processed file pair: 899804.ann and 899804.txt
# Processed file pair: 899806.ann and 899806.txt
# Processed file pair: 899808.ann and 899808.txt
# Processed file pair: 899810.ann and 899810.txt
# Processed file pair: 899812.ann and 899812.txt
# Processed file pair: 899814.ann and 899814.txt
# Processed file pair: 899816.ann and 899816.txt
# Processed file pair: 899818.ann and 899818.txt
# Processed file pair: 899820.ann and 899820.txt
# Processed file pair: 899822.ann and 899822.txt
# Processed file pair: 899824.ann and 899824.txt
# Processed file pair: 899826.ann and 899826.txt
# Processed file pair: 899828.ann and 899828.txt
# Processed file pair: 899830.ann and 899830.txt
# Processed file pair: 899832.ann and 899832.txt
# Processed file pair: 899834.ann and 899834.txt
# Processed file pair: 899836.ann and 899836.txt
# Processed file pair: 899838.ann and 899838.txt
# Processed file pair: 899840.ann and 899840.txt
# Processed file pair: 899842.ann and 899842.txt
# Processed file pair: 899844.ann and 899844.txt
# Processed file pair: 899846.ann and 899846.txt
# Processed file pair: 899854.ann and 899854.txt
# Processed file pair: 899858.ann and 899858.txt
# Processed file pair: 899860.ann and 899860.txt
# Processed file pair: 899862.ann and 899862.txt
# Processed file pair: 899864.ann and 899864.txt
# Processed file pair: 899868.ann and 899868.txt
# Processed file pair: 899870.ann and 899870.txt
# Processed file pair: 899872.ann and 899872.txt
# Processed file pair: 899874.ann and 899874.txt
# Processed file pair: 899876.ann and 899876.txt
# Processed file pair: 899878.ann and 899878.txt
# Processed file pair: 899880.ann and 899880.txt
# Processed file pair: 899882.ann and 899882.txt
# Processed file pair: 899884.ann and 899884.txt
# Processed file pair: 899888.ann and 899888.txt
# Processed file pair: 899890.ann and 899890.txt
# Processed file pair: 899892.ann and 899892.txt
# Processed file pair: 899894.ann and 899894.txt
# Processed file pair: 899896.ann and 899896.txt
# Processed file pair: 899898.ann and 899898.txt
# Processed file pair: 899900.ann and 899900.txt
# Processed file pair: 899902.ann and 899902.txt
# Processed file pair: 899904.ann and 899904.txt
# Processed file pair: 899906.ann and 899906.txt
# Processed file pair: 899908.ann and 899908.txt
# Processed file pair: 899910.ann and 899910.txt
# Processed file pair: 899912.ann and 899912.txt
# Processed file pair: 899914.ann and 899914.txt
# Processed file pair: 899916.ann and 899916.txt
# Processed file pair: 899918.ann and 899918.txt
# Processed file pair: 899920.ann and 899920.txt
# Processed file pair: 899922.ann and 899922.txt
# Processed file pair: 899926.ann and 899926.txt
# Processed file pair: 899932.ann and 899932.txt
# Processed file pair: 899934.ann and 899934.txt
# Processed file pair: 899936.ann and 899936.txt
# Processed file pair: 899938.ann and 899938.txt
# Processed file pair: 899940.ann and 899940.txt
# Processed file pair: 899944.ann and 899944.txt
# Processed file pair: 899946.ann and 899946.txt
# Processed file pair: 899948.ann and 899948.txt
# Processed file pair: 899950.ann and 899950.txt
# Processed file pair: 899952.ann and 899952.txt
# Processed file pair: 899954.ann and 899954.txt
# Processed file pair: 899956.ann and 899956.txt
# Processed file pair: 899958.ann and 899958.txt
# Processed file pair: 899960.ann and 899960.txt
# Processed file pair: 899962.ann and 899962.txt
# Processed file pair: 899964.ann and 899964.txt
# Processed file pair: 899968.ann and 899968.txt
# Processed file pair: 899970.ann and 899970.txt
# Processed file pair: 899972.ann and 899972.txt
# Processed file pair: 899974.ann and 899974.txt
# Processed file pair: 899976.ann and 899976.txt
# Processed file pair: 899978.ann and 899978.txt
# Processed file pair: 899980.ann and 899980.txt
# Processed file pair: 899982.ann and 899982.txt
# Processed file pair: 899984.ann and 899984.txt
# Processed file pair: 899986.ann and 899986.txt
# Processed file pair: 899988.ann and 899988.txt
# Processed file pair: 899990.ann and 899990.txt
# Processed file pair: 899992.ann and 899992.txt
# Processed file pair: 899994.ann and 899994.txt
# Processed file pair: 899996.ann and 899996.txt
# Processed file pair: 899998.ann and 899998.txt
# Processed file pair: 900002.ann and 900002.txt
# Processed file pair: 900004.ann and 900004.txt
# Processed file pair: 900006.ann and 900006.txt
# Processed file pair: 900010.ann and 900010.txt
# Processed file pair: 900012.ann and 900012.txt
# Processed file pair: 900014.ann and 900014.txt
# Processed file pair: 900016.ann and 900016.txt
# Processed file pair: 900020.ann and 900020.txt
# Processed file pair: 900024.ann and 900024.txt
# Processed file pair: 900026.ann and 900026.txt
# Processed file pair: 900030.ann and 900030.txt
# Processed file pair: 900032.ann and 900032.txt
# Processed file pair: 900034.ann and 900034.txt
# Processed file pair: 900036.ann and 900036.txt
# Processed file pair: 900038.ann and 900038.txt
# Processed file pair: 900040.ann and 900040.txt
# Processed file pair: 900042.ann and 900042.txt
# Processed file pair: 900044.ann and 900044.txt
# Processed file pair: 900046.ann and 900046.txt
# Processed file pair: 900048.ann and 900048.txt
# Processed file pair: 900050.ann and 900050.txt
# Processed file pair: 900052.ann and 900052.txt
# Processed file pair: 900054.ann and 900054.txt
# Processed file pair: 900056.ann and 900056.txt
# Processed file pair: 900058.ann and 900058.txt
# Processed file pair: 900060.ann and 900060.txt
# Processed file pair: 900062.ann and 900062.txt
# Processed file pair: 900064.ann and 900064.txt
# Processed file pair: 900066.ann and 900066.txt
# Processed file pair: 900068.ann and 900068.txt
# Processed file pair: 900070.ann and 900070.txt
# Processed file pair: 900072.ann and 900072.txt
# Processed file pair: 900074.ann and 900074.txt
# Processed file pair: 900076.ann and 900076.txt
# Processed file pair: 900078.ann and 900078.txt
# Processed file pair: 900080.ann and 900080.txt
# Processed file pair: 900084.ann and 900084.txt
# Processed file pair: 900086.ann and 900086.txt
# Processed file pair: 900090.ann and 900090.txt
# Processed file pair: 900092.ann and 900092.txt
# Processed file pair: 900094.ann and 900094.txt
# Processed file pair: 900096.ann and 900096.txt
# Processed file pair: 900100.ann and 900100.txt
# Processed file pair: 900102.ann and 900102.txt
# Processed file pair: 900104.ann and 900104.txt
# Processed file pair: 900108.ann and 900108.txt
# Processed file pair: 900110.ann and 900110.txt
# Processed file pair: 900112.ann and 900112.txt
# Processed file pair: 900114.ann and 900114.txt
# Processed file pair: 900116.ann and 900116.txt
# Processed file pair: 900120.ann and 900120.txt
# Processed file pair: 900122.ann and 900122.txt
# Processed file pair: 900124.ann and 900124.txt
# Processed file pair: 900126.ann and 900126.txt
# Processed file pair: 900128.ann and 900128.txt
# Processed file pair: 900130.ann and 900130.txt
# Processed file pair: 900132.ann and 900132.txt
# Processed file pair: 900134.ann and 900134.txt
# Processed file pair: 900136.ann and 900136.txt
# Processed file pair: 900138.ann and 900138.txt
# Processed file pair: 900140.ann and 900140.txt
# Processed file pair: 900142.ann and 900142.txt
# Processed file pair: 900144.ann and 900144.txt
# Processed file pair: 900146.ann and 900146.txt
# Processed file pair: 900148.ann and 900148.txt
# Processed file pair: 900150.ann and 900150.txt
# Processed file pair: 900156.ann and 900156.txt
# Processed file pair: 900158.ann and 900158.txt
# Processed file pair: 900160.ann and 900160.txt
# Processed file pair: 900168.ann and 900168.txt
# Processed file pair: 900170.ann and 900170.txt
# Processed file pair: 900174.ann and 900174.txt
# Processed file pair: 900176.ann and 900176.txt
# Processed file pair: 900178.ann and 900178.txt
# Processed file pair: 900180.ann and 900180.txt
# Processed file pair: 900182.ann and 900182.txt
# Processed file pair: 900184.ann and 900184.txt
# Processed file pair: 900186.ann and 900186.txt
# Processed file pair: 900188.ann and 900188.txt
# Processed file pair: 900190.ann and 900190.txt
# Processed file pair: 900192.ann and 900192.txt
# Processed file pair: 900194.ann and 900194.txt
# Processed file pair: 900196.ann and 900196.txt
# Processed file pair: 900198.ann and 900198.txt
# Processed file pair: 900202.ann and 900202.txt
# Processed file pair: 900204.ann and 900204.txt
# Processed file pair: 900206.ann and 900206.txt
# Processed file pair: 900208.ann and 900208.txt
# Processed file pair: 900210.ann and 900210.txt
# Processed file pair: 900212.ann and 900212.txt
# Processed file pair: 900214.ann and 900214.txt
# Processed file pair: 900216.ann and 900216.txt
# Processed file pair: 900218.ann and 900218.txt
# Processed file pair: 900220.ann and 900220.txt
# Processed file pair: 900222.ann and 900222.txt
# Processed file pair: 900224.ann and 900224.txt
# Processed file pair: 900226.ann and 900226.txt
# Processed file pair: 900228.ann and 900228.txt
# Processed file pair: 900230.ann and 900230.txt
# Processed file pair: 900232.ann and 900232.txt
# Processed file pair: 900234.ann and 900234.txt
# Processed file pair: 900238.ann and 900238.txt
# Processed file pair: 900240.ann and 900240.txt
# Processed file pair: 900244.ann and 900244.txt
# Processed file pair: 900246.ann and 900246.txt
# Processed file pair: 900248.ann and 900248.txt
# Processed file pair: 900250.ann and 900250.txt
# Processed file pair: 900252.ann and 900252.txt
# Processed file pair: 900254.ann and 900254.txt
# Processed file pair: 900256.ann and 900256.txt
# Processed file pair: 900258.ann and 900258.txt
# Processed file pair: 900260.ann and 900260.txt
# Processed file pair: 900262.ann and 900262.txt
# Processed file pair: 900264.ann and 900264.txt
# Processed file pair: 900266.ann and 900266.txt
# Processed file pair: 900270.ann and 900270.txt
# Processed file pair: 900272.ann and 900272.txt
# Processed file pair: 900274.ann and 900274.txt
# Processed file pair: 900276.ann and 900276.txt
# Processed file pair: 900278.ann and 900278.txt
# Processed file pair: 900282.ann and 900282.txt
# Processed file pair: 900284.ann and 900284.txt
# Processed file pair: 900286.ann and 900286.txt
# Processed file pair: 900288.ann and 900288.txt
# Processed file pair: 900290.ann and 900290.txt
# Processed file pair: 900292.ann and 900292.txt
# Processed file pair: 900298.ann and 900298.txt
# Processed file pair: 900302.ann and 900302.txt
# Processed file pair: 900312.ann and 900312.txt
# Processed file pair: 900320.ann and 900320.txt
# Processed file pair: 900324.ann and 900324.txt
# Processed file pair: 900328.ann and 900328.txt
# Processed file pair: 900334.ann and 900334.txt
# Processed file pair: 900342.ann and 900342.txt
# Processed file pair: 900344.ann and 900344.txt
# Processed file pair: 900346.ann and 900346.txt
# Processed file pair: 900348.ann and 900348.txt
# Processed file pair: 900350.ann and 900350.txt
# Processed file pair: 900352.ann and 900352.txt
# Processed file pair: 900354.ann and 900354.txt
# Processed file pair: 900356.ann and 900356.txt
